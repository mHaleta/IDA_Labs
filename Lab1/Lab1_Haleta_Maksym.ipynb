# %% [markdown]
# # Лабораторна робота №1
# # Агрегація ранжирувань отриманих з різних джерел з урахуванням їх важливості
#
# **Виконав: Галета М.С.**\
# **Група: КМ-91мп**

# %%
import numpy as np
from search_engines import *

# %%
class SearchQuery:
    def __init__(self, query, n_pages, n_results):
        self.query = query
        self.n_pages = n_pages
        self.n_results = n_results
        self.engines = [Google, Yahoo, Aol, Duckduckgo, Dogpile]
        self.results = None
        self.scores = None
    
    def custom_search(self):
        look = lambda x: pd.DataFrame()
        self.results = dict(
            zip(
                list(map(lambda engine: engine.__name__, self.engines)),
                list(
                    map(
                        lambda res: {
                            'title': res.titles()[:self.n_results],
                            'link': res.links()[:self.n_results],
                            'description': res.text()[:self.n_results]
                        },
                        list(
                            map(
                                lambda engine: engine().search(self.query, self.n_pages),
                                self.engines
                            )
                        )
                    )
                )
            )
        )
        
    def show_results(self):
        for engine in self.results.keys():
            print("========================== "+engine+" ==========================\n")
            for i in range(self.n_results):
                print("------------- Result {} -------------".format(i+1))
                print("Title: {}".format(self.results[engine]['title'][i]))
                print("Link: {}".format(self.results[engine]['link'][i]))
                print("Description: {}".format(self.results[engine]['description'][i]))
            print("\n\n")
    
    def calculate_scores(self):
        self.all_links = np.concatenate(np.array(list(map(lambda x: np.array(self.results[x]['link']), self.results.keys()))), axis=0)
        self.unique_links, self.occurences = np.unique(self.all_links, return_counts=True)
        self.scores = dict(
            zip(
                list(map(lambda engine: engine.__name__, self.engines)),
                list(
                    map(
                        lambda x: {
                            'alternatives': self.n_results,
                            'V': self.n_results/self.all_links.shape[0],
                            'O': self.n_results/self.unique_links.shape[0],
                            'E': 1
                        },
                        self.results.keys()
                    )
                )
            )
        )

# %%
class Ranking:
    def __init__(self, search_results, search_results_scores, all_links, unique_links, occurences):
        self.results = search_results
        self.scores = search_results_scores
        self.all_links = all_links
        self.unique_links = unique_links
        self.occurences = occurences
        
    def quantity_quality_weights(self):
        ro = np.sum(self.occurences)/(len(self.results.keys())*self.unique_links.shape[0])
        
        x1 = ro
        x2 = 1 - x1

        weights = np.array(list(map(lambda x: self.scores[x]['E']*(x1*self.scores[x]['O']+x2*self.scores[x]['V']), self.scores.keys())))
        weights /= np.sum(weights)

        return weights
    
    def statistical_weights(self):
        D_V = np.var(np.array(list(map(lambda x: self.scores[x]['V'], self.scores.keys()))))
        
        x1 = D_V
        x2 = 1 - x1

        weights = np.array(list(map(lambda x: self.scores[x]['E']*(x1*self.scores[x]['O']+x2*self.scores[x]['V']), self.scores.keys())))
        weights /= np.sum(weights)

        return weights
    
    def borda_ranking(self, weights):
        aggregation_ranks = [{link: i for i, link in enumerate(self.results[engine]['link'], start=1)} for engine in self.results.keys()]
 
        for engine_ranks in aggregation_ranks:
            m = len(engine_ranks)
            for link in self.unique_links:
                if link not in engine_ranks:
                    engine_ranks[link] = m + 1

        unique_links_ranks = {}
        for link in self.unique_links:
            link_rank = 0
            for engine_ranks, weight in zip(aggregation_ranks, weights):
                if link in engine_ranks:
                    link_rank += weight * engine_ranks[link]
            unique_links_ranks[link] = link_rank

        return np.array(sorted(unique_links_ranks.items(), key=lambda x: x[1]))
    
    def condorcet_ranking(self, weights):
        aggregation_ranks = [{link : i for i, link in enumerate(self.results[engine]['link'], start=1)} for engine in self.results.keys()]

        matrices = []
        for engine_ranks in aggregation_ranks:
            matrix = np.zeros((self.unique_links.shape[0], self.unique_links.shape[0]))
            for i in range(self.unique_links.shape[0]):
                for j in range(self.unique_links.shape[0]):
                    if i == j: 
                        matrix[i, j] = 0
                    elif self.unique_links[i] not in engine_ranks:
                        if self.unique_links[j] not in engine_ranks:
                            matrix[i, j] = 0
                        else:
                            matrix[i, j] = -1
                    elif self.unique_links[j] not in engine_ranks:
                        matrix[i, j] = 1
                    elif engine_ranks[self.unique_links[i]] < engine_ranks[self.unique_links[j]]: 
                        matrix[i, j] = 1
                    elif engine_ranks[self.unique_links[i]] > engine_ranks[self.unique_links[j]]: 
                        matrix[i, j] = -1
                    elif engine_ranks[self.unique_links[i]] == engine_ranks[self.unique_links[j]]: 
                        matrix[i, j] = 0
            matrices.append(matrix)

        ordinal_matrix = np.zeros((self.unique_links.shape[0], self.unique_links.shape[0]))
        for number in range(len(self.results.keys())):
            for i in range(self.unique_links.shape[0]):
                for j in range(self.unique_links.shape[0]):
                    ordinal_matrix[i, j] += (weights[number] * matrices[number][i, j])
 
        for i in range(self.unique_links.shape[0]):
            for j in range(self.unique_links.shape[0]):
                if ordinal_matrix[i, j] > 0:
                    ordinal_matrix[i, j] = 1
                elif ordinal_matrix[i, j] < 0:
                    ordinal_matrix[i, j] = -1
 
        all_ranks = ordinal_matrix.sum(1)

        unique_links_ranks = dict(zip(self.unique_links, all_ranks))
 
        return np.array(sorted(unique_links_ranks.items(), key=lambda x: x[1], reverse=True))
    
    def show(self, aggregated_results):
        for i in range(int(len(self.results.keys()) * 10 / 2)):
            for engine in self.results.keys():
                if aggregated_results[i, 0] in self.results[engine]["link"]:
                    source_index = self.results[engine]["link"].index(aggregated_results[i, 0])
                    print("-" * 10 + " Result {} ".format(i + 1) + "-" * 10)
                    print("Title: " + self.results[engine]["title"][source_index])
                    print("Description: " + self.results[engine]["description"][source_index])
                    print("Link: " + self.results[engine]["link"][source_index])
                    print("\n")
                    break

# %%
query = input("Введіть Ваш запит: ")
# Out:
# Введіть Ваш запит: Imagine Dragons

# %%
sq = SearchQuery(query, 2, 10)
sq.custom_search()
sq.calculate_scores()
results, scores, all_links, unique_links, occurences = sq.results, sq.scores, sq.all_links, sq.unique_links, sq.occurences

# %%
sq.show_results()
# Out:
# ========================== Google ==========================
#
# ------------- Result 1 -------------
# Title: Imagine Dragons - Believer - YouTubewww.youtube.com › watch
# Link: https://www.youtube.com/watch?v=7wtfhZwyrcc&list=PLxtMGPPd_qJPqhvbyIBHiowvbm_MtsW5A&index=33&t=0s
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# ------------- Result 2 -------------
# Title: Imagine Dragons - Radioactive - YouTubewww.youtube.com › watch
# Link: https://www.youtube.com/watch?v=ktvTqknDobU&list=PLlcmBuY0DD0uveef3_MCpJsW8flq4UbgN&index=9&t=0s
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# ------------- Result 3 -------------
# Title: Imagine Dragons — Вікіпедіяuk.wikipedia.org › wiki › Imagine_Dragons
# Link: https://uk.wikipedia.org/wiki/Imagine_Dragons
# Description: Imagine Dragons тричі отримували «American Music Award», п'ять разів — «Billboard Music Awards», одну нагороду Греммі та одну «World Music Award».
# ------------- Result 4 -------------
# Title: Imagine Dragons — Википедияru.wikipedia.org › wiki › Ima...
# Link: https://ru.wikipedia.org/wiki/Imagine_Dragons
# Description: «Imagine Dragons» (дословно «Вообрази Драконов») — американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали ...
# ------------- Result 5 -------------
# Title: Imagine Dragons - слушать и скачать бесплатноsefon.pro › artist › 547-imagi...
# Link: https://sefon.pro/artist/547-imagine-dragons/
# Description: Imagine Dragons: Believer, Natural, Bad Liar и еще 91 песня. Слушать и скачать бесплатно в хорошем качестве на Sefon.pro.
# ------------- Result 6 -------------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыкеmusic.yandex.ua › artist
# Link: https://music.yandex.ua/artist/675068
# Description: Imagine Dragons: Американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали известны после выпуска дебютного ...
# ------------- Result 7 -------------
# Title: Imagine Dragons | Official Sitewww.imaginedragonsmusic.com
# Link: https://www.imaginedragonsmusic.com/
# Description: Login · Home · News · Tour · About; Music. Music · Lyrics; Back. Videos · Photos · Store. Social Links. facebook · instagram · twitter · youtube_vevo · spotify ...
# ------------- Result 8 -------------
# Title: Imagine Dragons | ВКонтактеvk.com › idragons
# Link: https://vk.com/idragons
# Description: 8 лет назад Imagine Dragons выпустили свой первый официальный музыкальное клип «It's Time», который собрал более 450 миллионов просмотров на ...
# ------------- Result 9 -------------
# Title: Imagine Dragons: музыка, видео, статистика и фотографии ...www.last.fm › music › Imagin...
# Link: https://www.last.fm/ru/music/Imagine+Dragons
# Description: Слушай музыку от Imagine Dragons, похожую на Believer, Radioactive и не только. Новые композиции, альбомы и изображения от Imagine Dragons.
# ------------- Result 10 -------------
# Title: Imagine Dragons - Whatever It Takes - YouTubewww.youtube.com › watch
# Link: https://www.youtube.com/watch?v=gOsM-DYAEhY
# Description: Get Imagine Dragons' new album Evolve, out now: http://smarturl.it/EvolveID Shop Imagine Dragons: http ...
#
#
#
# ========================== Yahoo ==========================
#
# ------------- Result 1 -------------
# Title: Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/
# Description: Watch Imagine Dragons perform at the College Football Playoff National Championship January 7th... Watch the official video for 'Zero' below and listen to the song...
# ------------- Result 2 -------------
# Title: Imagine Dragons - Wikipedia
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# ------------- Result 3 -------------
# Title: ImagineDragons - YouTube
# Link: https://www.youtube.com/user/imaginedragons
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# ------------- Result 4 -------------
# Title: ImagineDragonsVEVO - YouTube
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# ------------- Result 5 -------------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Link: https://www.last.fm/music/Imagine+Dragons
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums). The band released four EPs - "Imagine Dragons" (… read more
# ------------- Result 6 -------------
# Title: Music | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/music
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# ------------- Result 7 -------------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The Latest ...
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# ------------- Result 8 -------------
# Title: Imagine Dragons on Amazon Music
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# ------------- Result 9 -------------
# Title: About | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/content/about
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# ------------- Result 10 -------------
# Title: Videos | | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/videos/all
# Description: Listen to Birds ft. Elisa: https://smarturl.it/BirdsID Get Origins, ft. Natural, Zero, Machine and Bad Liar, out now:...
#
#
#
# ========================== Aol ==========================
#
# ------------- Result 1 -------------
# Title: Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/
# Description: Watch Imagine Dragons perform at the College Football Playoff National Championship January 7th... Watch the official video for 'Zero' below and listen to the song...
# ------------- Result 2 -------------
# Title: Imagine Dragons - Wikipedia
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
# Description: Imagine Dragons is an American pop rock band from Las Vegas, Nevada, consisting of lead singer Dan Reynolds, lead guitarist Wayne Sermon, bassist Ben McKee, and drummer Daniel Platzman.
# ------------- Result 3 -------------
# Title: ImagineDragons - YouTube
# Link: https://www.youtube.com/user/imaginedragons
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# ------------- Result 4 -------------
# Title: ImagineDragonsVEVO - YouTube
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# ------------- Result 5 -------------
# Title: Imagine Dragons on Amazon Music
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# ------------- Result 6 -------------
# Title: Music | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/music
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# ------------- Result 7 -------------
# Title: Upcoming Dates | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/tour
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# ------------- Result 8 -------------
# Title: About | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/content/about
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world.
# ------------- Result 9 -------------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The ...
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# ------------- Result 10 -------------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Link: https://www.last.fm/music/Imagine+Dragons
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums).
#
#
#
# ========================== Duckduckgo ==========================
#
# ------------- Result 1 -------------
# Title: Imagine Dragons | Official Site
# Link: https://www.imaginedragonsmusic.com/
# Description: Watch Imagine Dragons perform at the College Football Playoff National Championship January 7th...
# ------------- Result 2 -------------
# Title: Imagine Dragons - Wikipedia
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
# Description: Imagine Dragons is an American pop rock band from Las Vegas, Nevada, consisting of lead singer Dan Reynolds, lead guitarist Wayne Sermon, bassist Ben McKee, and drummer Daniel Platzman.
# ------------- Result 3 -------------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Link: https://music.yandex.ua/artist/675068
# Description: Imagine Dragons: Американський інді-рок-гурт, утворений у 2008 році у Лас-Вегасі, штат Невада. До складу колективу входять вокаліст Ден Рейнольдс, гітарист Вейн Сермон...
# ------------- Result 4 -------------
# Title: Imagine Dragons - Home | Facebook
# Link: https://www.facebook.com/ImagineDragons/?fref=nf
# Description: See more of Imagine Dragons on Facebook.
# ------------- Result 5 -------------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Link: https://music.yandex.com/artist/675068/albums
# Description: Imagine Dragons. 2016 сингл From The Original Motion Picture "Passengers".
# ------------- Result 6 -------------
# Title: Imagine Dragons (@Imaginedragons) | Твиттер
# Link: https://twitter.com/imaginedragons
# Description: Imagine Dragons‏Подлинная учетная запись @Imaginedragons 8 нояб. 2018 г.
# ------------- Result 7 -------------
# Title: Imagine Dragons | ВКонтакте
# Link: https://vk.com/idragons
# Description: Imagine Dragons - это американская группа, исполняющая альтернативный рок, инди, инди-рок.
# ------------- Result 8 -------------
# Title: Imagine Dragons MP3 скачать бесплатно, новинки музыки Imagine...
# Link: https://muzofond.fm/collections/artists/imagine dragons
# Description: Скачай Imagine Dragons and Elisa Birds (2019) и Imagine Dragons and Lil Wayne Believer (2019). Imagine Dragons. Слушать исполнителя. 03:39.
# ------------- Result 9 -------------
# Title: Imagine Dragons Lyrics, Songs, and Albums | Genius
# Link: https://genius.com/artists/Imagine-dragons
# Description: Led by frontman Dan Reynolds, Imagine Dragons is an American alt-rock band that originated in Las Vegas. While the band began in 2008, the group boasted an entirely different.
# ------------- Result 10 -------------
# Title: Imagine Dragons | Free Listening on SoundCloud
# Link: https://soundcloud.com/imaginedragons
# Description: Stream Tracks and Playlists from Imagine Dragons on your desktop or mobile device.
#
#
#
# ========================== Dogpile ==========================
#
# ------------- Result 1 -------------
# Title: Imagine Dragons - Wikipedia
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# ------------- Result 2 -------------
# Title: Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/
# Description: Watch Imagine Dragons perform at the College Football Playoff National Championship January 7th... Watch the official video for 'Zero' below and listen to the song...
# ------------- Result 3 -------------
# Title: ImagineDragons - YouTube
# Link: https://www.youtube.com/user/imaginedragons
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# ------------- Result 4 -------------
# Title: ImagineDragonsVEVO - YouTube
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# ------------- Result 5 -------------
# Title: Imagine Dragons - Natural - YouTube
# Link: https://www.youtube.com/watch?v=0I647GU3Jsc
# Description: Unsubscribe from ImagineDragons? Sign in to add this video to a playlist. Sign in to report inappropriate content. Sign in to make your opinion count. Sign in to make your opinion count. The ...
# ------------- Result 6 -------------
# Title: Imagine Dragons - Mad World (Audio) - YouTube
# Link: https://www.youtube.com/watch?v=ZqmIFolThZo
# Description: Imagine Dragons - Mad World Cover All around me are familiar faces Worn out places, worn out faces Bright and early for their daily races Going nowhere, going nowhere And their tears are filling ...
# ------------- Result 7 -------------
# Title: Music | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/music
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# ------------- Result 8 -------------
# Title: About | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/content/about
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# ------------- Result 9 -------------
# Title: Upcoming Dates | Imagine Dragons
# Link: https://www.imaginedragonsmusic.com/tour
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# ------------- Result 10 -------------
# Title: Imagine Dragons playlist - BEST songs - YouTube
# Link: https://m.youtube.com/playlist?list=PLMEZyDHJojxOivUPWX1aasnKcpau8WZfP
# Description: The BEST songs of Imagine Dragons - an American rock band originating from Las Vegas, Nevada and consisting of lead vocalist Dan Reynolds, guitarist Wayne Sermon, bassist Ben McKee, and drummer Daniel Platzman.

# %%
r = Ranking(results, scores, all_links, unique_links, occurences)
qq_weights = r.quantity_quality_weights()
s_weights = r.quantity_quality_weights()

# %% [markdown]
# ## Модифікований метод Борда. Визначення відносної вагомості джерел інформації на основі кількості і якості наданої інформації

# %%
aggregated_results = r.borda_ranking(qq_weights)
r.show(aggregated_results)
# Out:
# ---------- Result 1 ----------
# Title: Imagine Dragons | Official Sitewww.imaginedragonsmusic.com
# Description: Login · Home · News · Tour · About; Music. Music · Lyrics; Back. Videos · Photos · Store. Social Links. facebook · instagram · twitter · youtube_vevo · spotify ...
# Link: https://www.imaginedragonsmusic.com/
#
#
# ---------- Result 2 ----------
# Title: Imagine Dragons - Wikipedia
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 3 ----------
# Title: ImagineDragons - YouTube
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# Link: https://www.youtube.com/user/imaginedragons
#
#
# ---------- Result 4 ----------
# Title: ImagineDragonsVEVO - YouTube
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
#
#
# ---------- Result 5 ----------
# Title: Music | Imagine Dragons
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# Link: https://www.imaginedragonsmusic.com/music
#
#
# ---------- Result 6 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыкеmusic.yandex.ua › artist
# Description: Imagine Dragons: Американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали известны после выпуска дебютного ...
# Link: https://music.yandex.ua/artist/675068
#
#
# ---------- Result 7 ----------
# Title: Imagine Dragons - Believer - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=7wtfhZwyrcc&list=PLxtMGPPd_qJPqhvbyIBHiowvbm_MtsW5A&index=33&t=0s
#
#
# ---------- Result 8 ----------
# Title: Imagine Dragons on Amazon Music
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
#
#
# ---------- Result 9 ----------
# Title: Imagine Dragons - Radioactive - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=ktvTqknDobU&list=PLlcmBuY0DD0uveef3_MCpJsW8flq4UbgN&index=9&t=0s
#
#
# ---------- Result 10 ----------
# Title: Imagine Dragons — Вікіпедіяuk.wikipedia.org › wiki › Imagine_Dragons
# Description: Imagine Dragons тричі отримували «American Music Award», п'ять разів — «Billboard Music Awards», одну нагороду Греммі та одну «World Music Award».
# Link: https://uk.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 11 ----------
# Title: About | Imagine Dragons
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# Link: https://www.imaginedragonsmusic.com/content/about
#
#
# ---------- Result 12 ----------
# Title: Imagine Dragons — Википедияru.wikipedia.org › wiki › Ima...
# Description: «Imagine Dragons» (дословно «Вообрази Драконов») — американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали ...
# Link: https://ru.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 13 ----------
# Title: Imagine Dragons | ВКонтактеvk.com › idragons
# Description: 8 лет назад Imagine Dragons выпустили свой первый официальный музыкальное клип «It's Time», который собрал более 450 миллионов просмотров на ...
# Link: https://vk.com/idragons
#
#
# ---------- Result 14 ----------
# Title: Imagine Dragons - Home | Facebook
# Description: See more of Imagine Dragons on Facebook.
# Link: https://www.facebook.com/ImagineDragons/?fref=nf
#
#
# ---------- Result 15 ----------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums). The band released four EPs - "Imagine Dragons" (… read more
# Link: https://www.last.fm/music/Imagine+Dragons
#
#
# ---------- Result 16 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Description: Imagine Dragons. 2016 сингл From The Original Motion Picture "Passengers".
# Link: https://music.yandex.com/artist/675068/albums
#
#
# ---------- Result 17 ----------
# Title: Imagine Dragons - слушать и скачать бесплатноsefon.pro › artist › 547-imagi...
# Description: Imagine Dragons: Believer, Natural, Bad Liar и еще 91 песня. Слушать и скачать бесплатно в хорошем качестве на Sefon.pro.
# Link: https://sefon.pro/artist/547-imagine-dragons/
#
#
# ---------- Result 18 ----------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The Latest ...
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
#
#
# ---------- Result 19 ----------
# Title: Upcoming Dates | Imagine Dragons
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# Link: https://www.imaginedragonsmusic.com/tour
#
#
# ---------- Result 20 ----------
# Title: Imagine Dragons - Natural - YouTube
# Description: Unsubscribe from ImagineDragons? Sign in to add this video to a playlist. Sign in to report inappropriate content. Sign in to make your opinion count. Sign in to make your opinion count. The ...
# Link: https://www.youtube.com/watch?v=0I647GU3Jsc
#
#
# ---------- Result 21 ----------
# Title: Imagine Dragons (@Imaginedragons) | Твиттер
# Description: Imagine Dragons‏Подлинная учетная запись @Imaginedragons 8 нояб. 2018 г.
# Link: https://twitter.com/imaginedragons
#
#
# ---------- Result 22 ----------
# Title: Imagine Dragons - Mad World (Audio) - YouTube
# Description: Imagine Dragons - Mad World Cover All around me are familiar faces Worn out places, worn out faces Bright and early for their daily races Going nowhere, going nowhere And their tears are filling ...
# Link: https://www.youtube.com/watch?v=ZqmIFolThZo
#
#
# ---------- Result 23 ----------
# Title: Imagine Dragons MP3 скачать бесплатно, новинки музыки Imagine...
# Description: Скачай Imagine Dragons and Elisa Birds (2019) и Imagine Dragons and Lil Wayne Believer (2019). Imagine Dragons. Слушать исполнителя. 03:39.
# Link: https://muzofond.fm/collections/artists/imagine dragons
#
#
# ---------- Result 24 ----------
# Title: Imagine Dragons Lyrics, Songs, and Albums | Genius
# Description: Led by frontman Dan Reynolds, Imagine Dragons is an American alt-rock band that originated in Las Vegas. While the band began in 2008, the group boasted an entirely different.
# Link: https://genius.com/artists/Imagine-dragons
#
#
# ---------- Result 25 ----------
# Title: Imagine Dragons: музыка, видео, статистика и фотографии ...www.last.fm › music › Imagin...
# Description: Слушай музыку от Imagine Dragons, похожую на Believer, Radioactive и не только. Новые композиции, альбомы и изображения от Imagine Dragons.
# Link: https://www.last.fm/ru/music/Imagine+Dragons

# %% [markdown]
# ## Модифікований метод Борда. Визначення відносної вагомості джерел інформації статистичним підходом

# %%
aggregated_results = r.borda_ranking(s_weights)
r.show(aggregated_results)
# Out:
# ---------- Result 1 ----------
# Title: Imagine Dragons | Official Sitewww.imaginedragonsmusic.com
# Description: Login · Home · News · Tour · About; Music. Music · Lyrics; Back. Videos · Photos · Store. Social Links. facebook · instagram · twitter · youtube_vevo · spotify ...
# Link: https://www.imaginedragonsmusic.com/
#
#
# ---------- Result 2 ----------
# Title: Imagine Dragons - Wikipedia
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 3 ----------
# Title: ImagineDragons - YouTube
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# Link: https://www.youtube.com/user/imaginedragons
#
#
# ---------- Result 4 ----------
# Title: ImagineDragonsVEVO - YouTube
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
#
#
# ---------- Result 5 ----------
# Title: Music | Imagine Dragons
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# Link: https://www.imaginedragonsmusic.com/music
#
#
# ---------- Result 6 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыкеmusic.yandex.ua › artist
# Description: Imagine Dragons: Американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали известны после выпуска дебютного ...
# Link: https://music.yandex.ua/artist/675068
#
#
# ---------- Result 7 ----------
# Title: Imagine Dragons - Believer - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=7wtfhZwyrcc&list=PLxtMGPPd_qJPqhvbyIBHiowvbm_MtsW5A&index=33&t=0s
#
#
# ---------- Result 8 ----------
# Title: Imagine Dragons on Amazon Music
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
#
#
# ---------- Result 9 ----------
# Title: Imagine Dragons - Radioactive - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=ktvTqknDobU&list=PLlcmBuY0DD0uveef3_MCpJsW8flq4UbgN&index=9&t=0s
#
#
# ---------- Result 10 ----------
# Title: Imagine Dragons — Вікіпедіяuk.wikipedia.org › wiki › Imagine_Dragons
# Description: Imagine Dragons тричі отримували «American Music Award», п'ять разів — «Billboard Music Awards», одну нагороду Греммі та одну «World Music Award».
# Link: https://uk.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 11 ----------
# Title: About | Imagine Dragons
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# Link: https://www.imaginedragonsmusic.com/content/about
#
#
# ---------- Result 12 ----------
# Title: Imagine Dragons — Википедияru.wikipedia.org › wiki › Ima...
# Description: «Imagine Dragons» (дословно «Вообрази Драконов») — американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали ...
# Link: https://ru.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 13 ----------
# Title: Imagine Dragons | ВКонтактеvk.com › idragons
# Description: 8 лет назад Imagine Dragons выпустили свой первый официальный музыкальное клип «It's Time», который собрал более 450 миллионов просмотров на ...
# Link: https://vk.com/idragons
#
#
# ---------- Result 14 ----------
# Title: Imagine Dragons - Home | Facebook
# Description: See more of Imagine Dragons on Facebook.
# Link: https://www.facebook.com/ImagineDragons/?fref=nf
#
#
# ---------- Result 15 ----------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums). The band released four EPs - "Imagine Dragons" (… read more
# Link: https://www.last.fm/music/Imagine+Dragons
#
#
# ---------- Result 16 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Description: Imagine Dragons. 2016 сингл From The Original Motion Picture "Passengers".
# Link: https://music.yandex.com/artist/675068/albums
#
#
# ---------- Result 17 ----------
# Title: Imagine Dragons - слушать и скачать бесплатноsefon.pro › artist › 547-imagi...
# Description: Imagine Dragons: Believer, Natural, Bad Liar и еще 91 песня. Слушать и скачать бесплатно в хорошем качестве на Sefon.pro.
# Link: https://sefon.pro/artist/547-imagine-dragons/
#
#
# ---------- Result 18 ----------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The Latest ...
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
#
#
# ---------- Result 19 ----------
# Title: Upcoming Dates | Imagine Dragons
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# Link: https://www.imaginedragonsmusic.com/tour
#
#
# ---------- Result 20 ----------
# Title: Imagine Dragons - Natural - YouTube
# Description: Unsubscribe from ImagineDragons? Sign in to add this video to a playlist. Sign in to report inappropriate content. Sign in to make your opinion count. Sign in to make your opinion count. The ...
# Link: https://www.youtube.com/watch?v=0I647GU3Jsc
#
#
# ---------- Result 21 ----------
# Title: Imagine Dragons (@Imaginedragons) | Твиттер
# Description: Imagine Dragons‏Подлинная учетная запись @Imaginedragons 8 нояб. 2018 г.
# Link: https://twitter.com/imaginedragons
#
#
# ---------- Result 22 ----------
# Title: Imagine Dragons - Mad World (Audio) - YouTube
# Description: Imagine Dragons - Mad World Cover All around me are familiar faces Worn out places, worn out faces Bright and early for their daily races Going nowhere, going nowhere And their tears are filling ...
# Link: https://www.youtube.com/watch?v=ZqmIFolThZo
#
#
# ---------- Result 23 ----------
# Title: Imagine Dragons MP3 скачать бесплатно, новинки музыки Imagine...
# Description: Скачай Imagine Dragons and Elisa Birds (2019) и Imagine Dragons and Lil Wayne Believer (2019). Imagine Dragons. Слушать исполнителя. 03:39.
# Link: https://muzofond.fm/collections/artists/imagine dragons
#
#
# ---------- Result 24 ----------
# Title: Imagine Dragons Lyrics, Songs, and Albums | Genius
# Description: Led by frontman Dan Reynolds, Imagine Dragons is an American alt-rock band that originated in Las Vegas. While the band began in 2008, the group boasted an entirely different.
# Link: https://genius.com/artists/Imagine-dragons
#
#
# ---------- Result 25 ----------
# Title: Imagine Dragons: музыка, видео, статистика и фотографии ...www.last.fm › music › Imagin...
# Description: Слушай музыку от Imagine Dragons, похожую на Believer, Radioactive и не только. Новые композиции, альбомы и изображения от Imagine Dragons.
# Link: https://www.last.fm/ru/music/Imagine+Dragons

# %% [markdown]
# ## Метод Кондорсе. Визначення відносної вагомості джерел інформації на основі кількості і якості наданої інформації

# %%
aggregated_results = r.condorcet_ranking(qq_weights)
r.show(aggregated_results)
# Out:
# ---------- Result 1 ----------
# Title: Imagine Dragons | Official Sitewww.imaginedragonsmusic.com
# Description: Login · Home · News · Tour · About; Music. Music · Lyrics; Back. Videos · Photos · Store. Social Links. facebook · instagram · twitter · youtube_vevo · spotify ...
# Link: https://www.imaginedragonsmusic.com/
#
#
# ---------- Result 2 ----------
# Title: Imagine Dragons - Wikipedia
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 3 ----------
# Title: ImagineDragons - YouTube
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# Link: https://www.youtube.com/user/imaginedragons
#
#
# ---------- Result 4 ----------
# Title: ImagineDragonsVEVO - YouTube
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
#
#
# ---------- Result 5 ----------
# Title: Music | Imagine Dragons
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# Link: https://www.imaginedragonsmusic.com/music
#
#
# ---------- Result 6 ----------
# Title: About | Imagine Dragons
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# Link: https://www.imaginedragonsmusic.com/content/about
#
#
# ---------- Result 7 ----------
# Title: Imagine Dragons on Amazon Music
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
#
#
# ---------- Result 8 ----------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The Latest ...
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
#
#
# ---------- Result 9 ----------
# Title: Upcoming Dates | Imagine Dragons
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# Link: https://www.imaginedragonsmusic.com/tour
#
#
# ---------- Result 10 ----------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums). The band released four EPs - "Imagine Dragons" (… read more
# Link: https://www.last.fm/music/Imagine+Dragons
#
#
# ---------- Result 11 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыкеmusic.yandex.ua › artist
# Description: Imagine Dragons: Американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали известны после выпуска дебютного ...
# Link: https://music.yandex.ua/artist/675068
#
#
# ---------- Result 12 ----------
# Title: Imagine Dragons | ВКонтактеvk.com › idragons
# Description: 8 лет назад Imagine Dragons выпустили свой первый официальный музыкальное клип «It's Time», который собрал более 450 миллионов просмотров на ...
# Link: https://vk.com/idragons
#
#
# ---------- Result 13 ----------
# Title: Imagine Dragons - Believer - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=7wtfhZwyrcc&list=PLxtMGPPd_qJPqhvbyIBHiowvbm_MtsW5A&index=33&t=0s
#
#
# ---------- Result 14 ----------
# Title: Imagine Dragons - Home | Facebook
# Description: See more of Imagine Dragons on Facebook.
# Link: https://www.facebook.com/ImagineDragons/?fref=nf
#
#
# ---------- Result 15 ----------
# Title: Imagine Dragons - Radioactive - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=ktvTqknDobU&list=PLlcmBuY0DD0uveef3_MCpJsW8flq4UbgN&index=9&t=0s
#
#
# ---------- Result 16 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Description: Imagine Dragons. 2016 сингл From The Original Motion Picture "Passengers".
# Link: https://music.yandex.com/artist/675068/albums
#
#
# ---------- Result 17 ----------
# Title: Imagine Dragons — Вікіпедіяuk.wikipedia.org › wiki › Imagine_Dragons
# Description: Imagine Dragons тричі отримували «American Music Award», п'ять разів — «Billboard Music Awards», одну нагороду Греммі та одну «World Music Award».
# Link: https://uk.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 18 ----------
# Title: Imagine Dragons - Natural - YouTube
# Description: Unsubscribe from ImagineDragons? Sign in to add this video to a playlist. Sign in to report inappropriate content. Sign in to make your opinion count. Sign in to make your opinion count. The ...
# Link: https://www.youtube.com/watch?v=0I647GU3Jsc
#
#
# ---------- Result 19 ----------
# Title: Imagine Dragons — Википедияru.wikipedia.org › wiki › Ima...
# Description: «Imagine Dragons» (дословно «Вообрази Драконов») — американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали ...
# Link: https://ru.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 20 ----------
# Title: Imagine Dragons (@Imaginedragons) | Твиттер
# Description: Imagine Dragons‏Подлинная учетная запись @Imaginedragons 8 нояб. 2018 г.
# Link: https://twitter.com/imaginedragons
#
#
# ---------- Result 21 ----------
# Title: Imagine Dragons - Mad World (Audio) - YouTube
# Description: Imagine Dragons - Mad World Cover All around me are familiar faces Worn out places, worn out faces Bright and early for their daily races Going nowhere, going nowhere And their tears are filling ...
# Link: https://www.youtube.com/watch?v=ZqmIFolThZo
#
#
# ---------- Result 22 ----------
# Title: Imagine Dragons - слушать и скачать бесплатноsefon.pro › artist › 547-imagi...
# Description: Imagine Dragons: Believer, Natural, Bad Liar и еще 91 песня. Слушать и скачать бесплатно в хорошем качестве на Sefon.pro.
# Link: https://sefon.pro/artist/547-imagine-dragons/
#
#
# ---------- Result 23 ----------
# Title: Videos | | Imagine Dragons
# Description: Listen to Birds ft. Elisa: https://smarturl.it/BirdsID Get Origins, ft. Natural, Zero, Machine and Bad Liar, out now:...
# Link: https://www.imaginedragonsmusic.com/videos/all
#
#
# ---------- Result 24 ----------
# Title: Imagine Dragons MP3 скачать бесплатно, новинки музыки Imagine...
# Description: Скачай Imagine Dragons and Elisa Birds (2019) и Imagine Dragons and Lil Wayne Believer (2019). Imagine Dragons. Слушать исполнителя. 03:39.
# Link: https://muzofond.fm/collections/artists/imagine dragons
#
#
# ---------- Result 25 ----------
# Title: Imagine Dragons playlist - BEST songs - YouTube
# Description: The BEST songs of Imagine Dragons - an American rock band originating from Las Vegas, Nevada and consisting of lead vocalist Dan Reynolds, guitarist Wayne Sermon, bassist Ben McKee, and drummer Daniel Platzman.
# Link: https://m.youtube.com/playlist?list=PLMEZyDHJojxOivUPWX1aasnKcpau8WZfP

# %% [markdown]
# ## Метод Кондорсе. Визначення відносної вагомості джерел інформації статистичним підходом

# %%
aggregated_results = r.condorcet_ranking(s_weights)
r.show(aggregated_results)
# Out:
# ---------- Result 1 ----------
# Title: Imagine Dragons | Official Sitewww.imaginedragonsmusic.com
# Description: Login · Home · News · Tour · About; Music. Music · Lyrics; Back. Videos · Photos · Store. Social Links. facebook · instagram · twitter · youtube_vevo · spotify ...
# Link: https://www.imaginedragonsmusic.com/
#
#
# ---------- Result 2 ----------
# Title: Imagine Dragons - Wikipedia
# Description: Imagine Dragons were part of the Wayhome summer 2017 lineup in Oro-Medonte, Ontario. On April 27, 2017, Imagine Dragons released "Thunder" as the second single from their third album. On May 8, 2017, Imagine Dragons announced their third studio album Evolve, as well as a new track "Whatever It Takes", which was released on the same day.
# Link: https://en.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 3 ----------
# Title: ImagineDragons - YouTube
# Description: ImagineDragonsVEVO. ImagineDragonsVEVO. Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more... All New ALTERNATIVE. Imagine Dragons - Bad Liar (Official Audio ...
# Link: https://www.youtube.com/user/imaginedragons
#
#
# ---------- Result 4 ----------
# Title: ImagineDragonsVEVO - YouTube
# Description: Imagine Dragons on Vevo - Official Music Videos, Live Performances, Interviews and more...
# Link: https://m.youtube.com/user/ImagineDragonsVEVO
#
#
# ---------- Result 5 ----------
# Title: Music | Imagine Dragons
# Description: Believer (feat. Lil Wayne) Imagine Dragons. Imagine Dragons. Origins (Deluxe) Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons. Zero - From the Original Motion Picture "Ralph Breaks The Internet" Imagine Dragons. Bullet In A Gun. Imagine Dragons. Imagine Dragons. Imagine Dragons. Imagine Dragons.
# Link: https://www.imaginedragonsmusic.com/music
#
#
# ---------- Result 6 ----------
# Title: About | Imagine Dragons
# Description: After releasing their 2012 full-length debut Night Visions (featuring the Grammy Award-winning single “Radioactive”), Imagine Dragons spent nearly two years bringing their passionately inventive brand of alt-rock to arenas around the world. To deal with the chaos of a touring schedule that included 130 headline dates and 50 festivals across the globe, the Las Vegas-based quartet threw ...
# Link: https://www.imaginedragonsmusic.com/content/about
#
#
# ---------- Result 7 ----------
# Title: Imagine Dragons on Amazon Music
# Description: Check out Imagine Dragons on Amazon Music. Stream ad-free or purchase CD's and MP3s now on Amazon.
# Link: https://www.amazon.com/Imagine-Dragons/e/B007AUFJKY
#
#
# ---------- Result 8 ----------
# Title: Imagine Dragons Radio: Listen to Free Music & Get The Latest ...
# Description: Winning their first Grammy Award in 2014 for the hit single "Radioactive" from their debut album, Night Visions, Imagine Dragons remained near the top of the charts for much of the 2010s, topping the Billboard 200 with 2015's Smoke + Mirrors.
# Link: https://www.iheart.com/artist/imagine-dragons-561823/
#
#
# ---------- Result 9 ----------
# Title: Upcoming Dates | Imagine Dragons
# Description: By submitting this form, you agree to the Universal Music Group Privacy Policy.
# Link: https://www.imaginedragonsmusic.com/tour
#
#
# ---------- Result 10 ----------
# Title: Imagine Dragons music, videos, stats, and photos | Last.fm
# Description: Imagine Dragons is a Grammy award-winning alternative rock band which formed in 2008 in Las Vegas, Nevada, United States. The band consists of Dan Reynolds (vocals), Wayne Sermon (guitar), Ben McKee (bass) and Daniel Platzman (drums). The band released four EPs - "Imagine Dragons" (… read more
# Link: https://www.last.fm/music/Imagine+Dragons
#
#
# ---------- Result 11 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыкеmusic.yandex.ua › artist
# Description: Imagine Dragons: Американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали известны после выпуска дебютного ...
# Link: https://music.yandex.ua/artist/675068
#
#
# ---------- Result 12 ----------
# Title: Imagine Dragons | ВКонтактеvk.com › idragons
# Description: 8 лет назад Imagine Dragons выпустили свой первый официальный музыкальное клип «It's Time», который собрал более 450 миллионов просмотров на ...
# Link: https://vk.com/idragons
#
#
# ---------- Result 13 ----------
# Title: Imagine Dragons - Believer - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=7wtfhZwyrcc&list=PLxtMGPPd_qJPqhvbyIBHiowvbm_MtsW5A&index=33&t=0s
#
#
# ---------- Result 14 ----------
# Title: Imagine Dragons - Home | Facebook
# Description: See more of Imagine Dragons on Facebook.
# Link: https://www.facebook.com/ImagineDragons/?fref=nf
#
#
# ---------- Result 15 ----------
# Title: Imagine Dragons - Radioactive - YouTubewww.youtube.com › watch
# Description: Enjoy the videos and music you love, upload original content, and share it all with friends, family, and the world ...
# Link: https://www.youtube.com/watch?v=ktvTqknDobU&list=PLlcmBuY0DD0uveef3_MCpJsW8flq4UbgN&index=9&t=0s
#
#
# ---------- Result 16 ----------
# Title: Imagine Dragons — слушать онлайн на Яндекс.Музыке
# Description: Imagine Dragons. 2016 сингл From The Original Motion Picture "Passengers".
# Link: https://music.yandex.com/artist/675068/albums
#
#
# ---------- Result 17 ----------
# Title: Imagine Dragons — Вікіпедіяuk.wikipedia.org › wiki › Imagine_Dragons
# Description: Imagine Dragons тричі отримували «American Music Award», п'ять разів — «Billboard Music Awards», одну нагороду Греммі та одну «World Music Award».
# Link: https://uk.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 18 ----------
# Title: Imagine Dragons - Natural - YouTube
# Description: Unsubscribe from ImagineDragons? Sign in to add this video to a playlist. Sign in to report inappropriate content. Sign in to make your opinion count. Sign in to make your opinion count. The ...
# Link: https://www.youtube.com/watch?v=0I647GU3Jsc
#
#
# ---------- Result 19 ----------
# Title: Imagine Dragons — Википедияru.wikipedia.org › wiki › Ima...
# Description: «Imagine Dragons» (дословно «Вообрази Драконов») — американская инди-рок-группа, образованная в 2008 году в городе Лас-Вегас, США. Стали ...
# Link: https://ru.wikipedia.org/wiki/Imagine_Dragons
#
#
# ---------- Result 20 ----------
# Title: Imagine Dragons (@Imaginedragons) | Твиттер
# Description: Imagine Dragons‏Подлинная учетная запись @Imaginedragons 8 нояб. 2018 г.
# Link: https://twitter.com/imaginedragons
#
#
# ---------- Result 21 ----------
# Title: Imagine Dragons - Mad World (Audio) - YouTube
# Description: Imagine Dragons - Mad World Cover All around me are familiar faces Worn out places, worn out faces Bright and early for their daily races Going nowhere, going nowhere And their tears are filling ...
# Link: https://www.youtube.com/watch?v=ZqmIFolThZo
#
#
# ---------- Result 22 ----------
# Title: Imagine Dragons - слушать и скачать бесплатноsefon.pro › artist › 547-imagi...
# Description: Imagine Dragons: Believer, Natural, Bad Liar и еще 91 песня. Слушать и скачать бесплатно в хорошем качестве на Sefon.pro.
# Link: https://sefon.pro/artist/547-imagine-dragons/
#
#
# ---------- Result 23 ----------
# Title: Videos | | Imagine Dragons
# Description: Listen to Birds ft. Elisa: https://smarturl.it/BirdsID Get Origins, ft. Natural, Zero, Machine and Bad Liar, out now:...
# Link: https://www.imaginedragonsmusic.com/videos/all
#
#
# ---------- Result 24 ----------
# Title: Imagine Dragons MP3 скачать бесплатно, новинки музыки Imagine...
# Description: Скачай Imagine Dragons and Elisa Birds (2019) и Imagine Dragons and Lil Wayne Believer (2019). Imagine Dragons. Слушать исполнителя. 03:39.
# Link: https://muzofond.fm/collections/artists/imagine dragons
#
#
# ---------- Result 25 ----------
# Title: Imagine Dragons playlist - BEST songs - YouTube
# Description: The BEST songs of Imagine Dragons - an American rock band originating from Las Vegas, Nevada and consisting of lead vocalist Dan Reynolds, guitarist Wayne Sermon, bassist Ben McKee, and drummer Daniel Platzman.
# Link: https://m.youtube.com/playlist?list=PLMEZyDHJojxOivUPWX1aasnKcpau8WZfP
